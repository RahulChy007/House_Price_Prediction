# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../data/raw/housing.csv')
df.head()
# Out:
#    area  bedrooms  bathrooms   price
# 0  2600         3          2  550000
# 1  3000         4          3  565000
# 2  3200         3          2  610000
# 3  3600         3          2  595000
# 4  4000         5          3  760000

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   area       7 non-null      int64
#  1   bedrooms   7 non-null      int64
#  2   bathrooms  7 non-null      int64
#  3   price      7 non-null      int64
# dtypes: int64(4)
# memory usage: 356.0 bytes
#               area  bedrooms  bathrooms          price
# count     7.000000  7.000000   7.000000       7.000000
# mean   3700.000000  3.857143   2.714286  675714.285714
# std     854.400375  0.899735   0.755929  123707.604571
# min    2600.000000  3.000000   2.000000  550000.000000
# 25%    3100.000000  3.000000   2.000000  580000.000000
# 50%    3600.000000  4.000000   3.000000  610000.000000
# 75%    4250.000000  4.500000   3.000000  780000.000000
# max    5000.000000  5.000000   4.000000  850000.000000

# %%
df.isnull().sum()
# Out:
# area         0
# bedrooms     0
# bathrooms    0
# price        0
# dtype: int64

# %%
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
sns.histplot(df['price'], bins=10, kde=True)
plt.title("Price Distribution")
plt.show()

# %%
df.to_csv('../data/processed/cleaned_data.csv', index=False)
